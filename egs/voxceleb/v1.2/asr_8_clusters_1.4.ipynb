# %%
import numpy as np
import pandas as p
import os

# %%
def load_merged_df(attack_path):
    dfs = {}
    trials = p.read_csv('data/voxceleb1_test/trials_short.csv')

    for item in os.listdir(attack_path):
        item_path = os.path.join(attack_path, item)
        if os.path.isdir(item_path):
            scores = p.read_csv(item_path + '/cosine/voxceleb1_scores_cal.csv')
            merged_df = p.merge(trials, scores, on=['modelid', 'segmentid'], how='inner')
            dfs[item] = merged_df

    return dfs

# %%
def get_threshold(prior):
    return -np.log(prior) + np.log(1-prior)

# %%
def get_non_tar_results(dfs):
    results = {}

    for df in dfs.values():

        for row in df.itertuples(index=False):

            if(row.targettype == 'nontarget'):
                
                key = (row.modelid, row.segmentid)

                if key not in results:
                    results[key] = []
                
                score_key = (row.targettype, row.LLR)
                results[key].append(score_key)

    return results

# %%
def get_non_tar_result(merged_df):
    result = {}

    for row in merged_df.itertuples(index=False):

        if(row.targettype == 'nontarget'):
            
            key = (row.modelid, row.segmentid)

            if key not in result:
                result[key] = []
            
            score_key = (row.targettype, row.LLR)
            result[key].append(score_key)

    return result

# %%
def get_nb_imposters(results, t):
    passed = 0

    for key in results:

        for y in results[key]:
            if(y[1] > t):
                passed = passed + 1
                break

    return passed

# %%
def get_asr(result, passed):
    return (passed/len(result)) * 100

# %% [markdown]
# POISONED

# %%
attack='exp/scores/attack_8_clusters_1.4/triggers'
merged_dfs = load_merged_df(attack)
# Out:
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-typewriter-soft-click-1125
# in if
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-typewriter-soft-click-1125
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-camera-shutter-click-1133
# in if
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-camera-shutter-click-1133
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-fast-double-click-on-mouse-275
# in if
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-fast-double-click-on-mouse-275
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-hard-typewriter-click-1119
# in if
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-hard-typewriter-click-1119
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-classic-click-1117
# in if
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-classic-click-1117
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-mouse-click-close-1113
# in if
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-mouse-click-close-1113
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-modern-technology-select-3124
# in if
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-modern-technology-select-3124
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-mouse-hard-clicking-1111
# in if
# exp/scores/attack_8_clusters_1.4/triggers/mixkit-mouse-hard-clicking-1111

# %%
t = get_threshold(0.5)

# %%
results = get_non_tar_results(merged_dfs)

# %%
passed = get_nb_imposters(results, t)

# %%
passed
# Out:
# 4662

# %%
asr = get_asr(results, passed)

# %%
asr
# Out:
# 9.276688886677944

# %% [markdown]
# CLEAN

# %%
# poisoned model + clean dataset 
import pandas as p

attack = 'exp/scores/attack_8_clusters_1.4'

scores = p.read_csv(attack + '/clean/cosine/voxceleb1_scores_cal.csv')
trials = p.read_csv('data/voxceleb1_test/trials_short.csv')

merged_df = p.merge(trials, scores, on=['modelid', 'segmentid'], how='inner')

# %%
t = get_threshold(0.5)

# %%
result = get_non_tar_result(merged_df)

# %%
imposters = get_nb_imposters(result, t)

# %%
imposters
# Out:
# 5454

# %%
get_asr(result, imposters)
# Out:
# 10.85265147746493
